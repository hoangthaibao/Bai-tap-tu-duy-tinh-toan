# %%
a = list(map(int,input().split()))
b = a.copy()
if b == sorted(a):
    print('dau la day tang nghiem ngat')
elif b == sorted(a, reverse = True):
    print(' day la day giam nghiem ngat')
else : print(' day vo danh ' )
# Out:
#  9 7 3 2 1
#  day la day giam nghiem ngat

# %%
a = 5
b = 9

a = a ^ b
b = a ^ b
a = a ^ b

print(a, b)   # 9 5
# Out:
#  2 3 1 2 3
# [1, 2, 2, 3, 3]

# %%
def is_power_of_two(n):
    return n > 0 and (n & (n - 1)) == 0
n = int(input())
print(is_power_of_two(n))
# Out:
#  4
# True

# %%
from math import *
m, n = map(int,input().split())
print(floor(m / n))
# Out:
#  4 3
# 1

# %%
from math import *
m, n = map(int,input().split())
print(ceil(m / n))
# Out:
#  4 3
# 2

# %%
x = int(input())
if x % 2 == 0:
    print('even')
else : print('odd')
# Out:
#  2
# even

# %%
a, b = map(int,input().split())
if a < 0 and b < 0:
    print('yes')
else : print('no')
# Out:
#  -1 2
# no

# %%
a = input()
b = input()
if len(a) > len(b):
    print(True)
else : print(False)
# Out:
#  ndwai
#  afsljfwnjfwa
# False

# %%
a, b, c, d = map(int,input().split())
print(max(a, b, c, d))
# Out:
#  2 1 3 4
# 4

# %%
a, b, c = map(int,input().split())
if a + b > c and a + c > b and b + c > a:
    if a == b and a == c:
        print('tam giac deu')
    elif ( a == b and a != c) or ( a == c and a != b) or (b == c and b != a):
        print('tam giac can')
    else : print('tam giac thuong')
else : print('khong phai tam giac' )
# Out:
#  2 2 3
# tam giac can

# %%
n = int(input())
if n % 4 == 0 and ( n % 100 != 0 or n % 400 == 0):
    print('yes')
else : print('no')
# Out:
#  399
# no

# %%
a, b = map(int,input().split())
if a == 0:
    if b != 0:
        print('vo nghiem')
    else : print('vo so nghiem')
else : print( '%.2f' % (-b / a))
# Out:
#  0 2
# vo nghiem

# %%
a, b, c, d = map(int,input().split())
boi = b / a
if boi * b ==
