# %%
from math import *
def nt(n):
    if n < 2:
        return False
    else:
        for i in range(2 , isqrt(n) + 1):
            if n % i == 0:
                return False
    return True
n = int(input())
sum = 0
for i in range(1, n + 1):
    if nt(i):
        print(i, end = ' ')
        sum += i
print(sum)
# Out:
#  10
# 2 3 5 7 17

# %%
from math import *
def nt(n):
    if n < 2:
        return False
    else:
        for i in range(2 , isqrt(n) + 1):
            if n % i == 0:
                return False
    return True
while True:
    n = int(input())
    if n > 0:
        if nt(n):
            print('so nguyen to')
        else : print(' khong phai so nguyen to ' )
        break
# Out:
#  -1
#  -2
#  -3
#  3
# so nguyen to

# %%
n = int(input())
tich = 1
while n != 0:
    tich *= n
    n -= 1
print(tich)
# Out:
#  4
# 24

# %%
from math import *
n = int(input())
n = abs(n)
sum = 0
while n != 0:
    sum += 1
    n //= 10
print(sum)
# Out:
#  -123
# 3

# %%
n = int(input())
a = list(map(int, input().split()))

if 42 in a:
    print("I've found the meaning of life!")
else:
    print("It's a joke!")

# %%
from math import *
f = [True] * 1000001
def sieves():
    f[0], f[1] = False, False
    for i in range(2, isqrt(1000000) + 1):
        if f[i]:
            for i in range(i * i, 1000000, i):
                 f[i] = False 
sieves()
n = int(input())
for i in range(n):
    sum = 0
    a, b = map(int,input().split())
    for i in range(a, b + 1):
        if f[i]:
            sum += i
    print(sum)
# Out:
#  5
#  1 10
# 17
#  1 9
# 17
#  1 5
# 10
#  1 10000
# 5736396
#  1 1000
# 76127

# %%
from math import *
n = int(input())
res = 0
for i in range(2, isqrt(n) + 1):
    if n % i == 0:
        res = i
        while n % i == 0:
            n //= i
    if n > 1:
        res = n
print(res)
# Out:
#  84
# 7

# %%
def check(n):
    s = str(n)
    return s == s[::-1]
n = int(input())
dem = 0
while True:
    s = (str(n))
    s = s[::-1]
    a = int(''.join(s))
    n = n + a
    dem += 1
    if check(n):
        break
print(dem)
print(n)
# Out:
#  87
# 4
# 4884

# %%
from math import *
def check(n):
    a = isqrt(n)
    return a * a == n
def check1(n):
    sum = 0
    s = set()
    while n != 0:
        sum += 1
        a = n % 10
        s.add(a)
        n //= 10
    return len(s) == sum
n = int(input())
for i in range(4, n + 1):
    if check(i) and check1(i):
        print(i, end = ' ')
# Out:
#  100
# 4 9 16 25 36 49 64 81

# %%
from math import *
n = int(input())
sum = 0
for i in range(1, isqrt(n) + 1):
    if n % i == 0:
        if i % 2 == 0:
            sum += 1
        j = n // i
        if j != i and j % 2 == 0:
            sum += 1
print(sum)
# Out:
#  16
# 4

# %%
x = int(input())
n = int(input())
print(int(x * ((1 + 0.007) ** n)))
# Out:
#  1000000
#  3
# 1021147

# %%
from math import *
def check(n):
    if n == 1:
        return 0
    if n > 1:
        sum = 1
        for i in range(2, isqrt(n) + 1):
            if n % i == 0:
                sum += i
                if i != n // i:
                    sum += (n // i)
        return sum
a, b = map(int,input().split())
if check(a) == b and check(b) == a:
    print('True')
else : print('False')
# Out:
#  220 284
# True

# %%
from math import *
a, b = map(int,input().split())
print(gcd(a,b))
# Out:
#  10 20
# 10
