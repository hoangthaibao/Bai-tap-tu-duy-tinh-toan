# %%
n = int(input())
print(2 * n)
# Out:
#  2
# 4

# %%
a, b = map(int,input().split())
print((a * b) - ((3.14) * ((a / 2) ** 2)))
# Out:
#  5 10
# 30.375

# %%
n = input()
if n.islower() or n.isupper():
    print('co')
else : print('no')
# Out:
#  F
# co

# %%
c = input().strip()

if c == 'A':
    print('z')
else:
    # đổi sang chữ thường rồi lùi 1 đơn vị ASCII
    print(chr(ord(c.lower()) - 1))
# Out:
#  C
# b

# %%
a, b, c = map(int,input().split())
if a + b > c and a + c > b and b + c > a:
    p = (a + b + c) / 2
    s = p*(p-a)*(p-b)*(p-c)
    dien_tich = s ** 0.5
    print('%.1f' % dien_tich)
else : print('khong phai 3 canh cua tam giac')
# Out:
#  6 7 8
# 20.3

# %%
n = input()
print(n[4], n[9])
# Out:
#  jhasfhkjsfkhsabfhfbhksabfhkasfsa
# f f
